# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#         Unnamed: 0              Unnamed: 1  Unnamed: 2             Unnamed: 3  \
# 0            Actor              Debut Film  Debut Year  Total Films (Approx.)
# 1   Shah Rukh Khan                 Deewana        1992                     65
# 2      Salman Khan         Biwi Ho To Aisi        1988                     85
# 3       Aamir Khan  Qayamat Se Qayamat Tak        1988                     46
# 4     Akshay Kumar                Saugandh        1991                    150
# 5       Ajay Devgn        Phool Aur Kaante        1991                    115
# 6   Hrithik Roshan   Kaho Naa... Pyaar Hai        2000                     33
# 7    Ranbir Kapoor               Saawariya        2007                     22
# 8    Ranveer Singh      Band Baaja Baaraat        2010                     20
# 9     Varun Dhawan     Student of the Year        2012                     20
# 10   Kartik Aaryan      Pyaar Ka Punchnama        2011                     16
#
# ...

# %%
 df.loc[1]
# Out:
# Unnamed: 0    Shah Rukh Khan
# Unnamed: 1           Deewana
# Unnamed: 2              1992
# Unnamed: 3                65
# Unnamed: 4                42
# Unnamed: 5                23
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Unnamed: 0    Shah Rukh Khan
# Unnamed: 1           Deewana
# Unnamed: 2              1992
# Unnamed: 3                65
# Unnamed: 4                42
# Unnamed: 5                23
# Name: 1, dtype: object

# %%
df.loc[0, "Debut Year"]
# Out:
# '1992'

# %%
import pandas as pd

df = pd.read_csv("dataset.csv")

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df.columns = df.iloc[0]   # Make first row the column names
df = df[1:]               # Remove the first row
df.reset_index(drop=True, inplace=True)

# %%
df.columns
# Out:
# Index(['Actor', 'Debut Film', 'Debut Year', 'Total Films (Approx.)',
#        'Hit Count (Approx.)', 'Flop Count (Approx.)'],
#       dtype='object', name=0)

# %%
df.iloc[7,5]
# Out:
# '7'

# %%
df.loc[0:7],["Actor", "Debut Year"]
# Out:
# (0           Actor              Debut Film Debut Year Total Films (Approx.)  \
#  0  Shah Rukh Khan                 Deewana       1992                    65
#  1     Salman Khan         Biwi Ho To Aisi       1988                    85
#  2      Aamir Khan  Qayamat Se Qayamat Tak       1988                    46
#  3    Akshay Kumar                Saugandh       1991                   150
#  4      Ajay Devgn        Phool Aur Kaante       1991                   115
#  5  Hrithik Roshan   Kaho Naa... Pyaar Hai       2000                    33
#  6   Ranbir Kapoor               Saawariya       2007                    22
#  7   Ranveer Singh      Band Baaja Baaraat       2010                    20
#
#  0 Hit Count (Approx.) Flop Count (Approx.)
#  0                  42                   23
#  1                  50                   35
#  2                  33                   13
#  3                  72                   78
#  4                  60                   55
# ...

# %%
df.iloc[0:2,0:2]
# Out:
# 0           Actor       Debut Film
# 0  Shah Rukh Khan          Deewana
# 1     Salman Khan  Biwi Ho To Aisi

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df[df['Debut Year']>1992]
# Out:
# 0           Actor             Debut Film  Debut Year  Total Films (Approx.)  \
# 5  Hrithik Roshan  Kaho Naa... Pyaar Hai        2000                     33
# 6   Ranbir Kapoor              Saawariya        2007                     22
# 7   Ranveer Singh     Band Baaja Baaraat        2010                     20
# 8    Varun Dhawan    Student of the Year        2012                     20
# 9   Kartik Aaryan     Pyaar Ka Punchnama        2011                     16
#
# 0  Hit Count (Approx.)  Flop Count (Approx.)
# 5                   22                    11
# 6                   14                     8
# 7                   13                     7
# 8                   14                     6
# 9                   10                     6

# %%
print(df.dtypes)
# Out:
# 0
# Actor                    object
# Debut Film               object
# Debut Year               object
# Total Films (Approx.)    object
# Hit Count (Approx.)      object
# Flop Count (Approx.)     object
# dtype: object

# %%
df["Debut Year"] = pd.to_numeric(df["Debut Year"])
df["Total Films (Approx.)"] = pd.to_numeric(df["Total Films (Approx.)"])
df["Hit Count (Approx.)"] = pd.to_numeric(df["Hit Count (Approx.)"])
df["Flop Count (Approx.)"] = pd.to_numeric(df["Flop Count (Approx.)"])

# %%
df["Debut Year"] = pd.to_numeric(df["Debut Year"], errors="coerce")

# %%
df[df["Debut Year"] > 1992]
# Out:
# 0           Actor             Debut Film  Debut Year  Total Films (Approx.)  \
# 5  Hrithik Roshan  Kaho Naa... Pyaar Hai        2000                     33
# 6   Ranbir Kapoor              Saawariya        2007                     22
# 7   Ranveer Singh     Band Baaja Baaraat        2010                     20
# 8    Varun Dhawan    Student of the Year        2012                     20
# 9   Kartik Aaryan     Pyaar Ka Punchnama        2011                     16
#
# 0  Hit Count (Approx.)  Flop Count (Approx.)
# 5                   22                    11
# 6                   14                     8
# 7                   13                     7
# 8                   14                     6
# 9                   10                     6

# %%
df.query("`Debut Year` > 2000")
# Out:
# 0          Actor           Debut Film  Debut Year  Total Films (Approx.)  \
# 6  Ranbir Kapoor            Saawariya        2007                     22
# 7  Ranveer Singh   Band Baaja Baaraat        2010                     20
# 8   Varun Dhawan  Student of the Year        2012                     20
# 9  Kartik Aaryan   Pyaar Ka Punchnama        2011                     16
#
# 0  Hit Count (Approx.)  Flop Count (Approx.)
# 6                   14                     8
# 7                   13                     7
# 8                   14                     6
# 9                   10                     6

# %%
df2 = df[['Actor', 'Debut Year']]

# %%
df2
# Out:
# 0           Actor  Debut Year
# 0  Shah Rukh Khan        1992
# 1     Salman Khan        1988
# 2      Aamir Khan        1988
# 3    Akshay Kumar        1991
# 4      Ajay Devgn        1991
# 5  Hrithik Roshan        2000
# 6   Ranbir Kapoor        2007
# 7   Ranveer Singh        2010
# 8    Varun Dhawan        2012
# 9   Kartik Aaryan        2011

# %%
df2 = df[['Actor', 'Debut Year']].copy()
